# %% [markdown]
# # Combine videos sequentially

# %%
from moviepy.editor import VideoFileClip, concatenate_videoclips
import re

# List of paths to the video files
video_paths = [r"C:\Users\11\Documents\2024-08-11 11-46-26.mp4", r"C:\Users\11\Documents\2024-08-11 11-52-27.mp4"]

# Load the video clips
video_clips = [VideoFileClip(video) for video in video_paths]

# Combine the videos one after another
combined = concatenate_videoclips(video_clips)

# Write the result to a file
combined.write_videofile(r"C:\Users\11\Documents\combined_video.mp4")

# %% [markdown]
# # Trim Video duration

# %%
from moviepy.video.io.VideoFileClip import VideoFileClip

def trim_video(input_path, output_path, duration=300):
    """
    Trims the video to the specified duration and saves it to a new file.

    :param input_path: Path to the input video file.
    :param output_path: Path to save the trimmed video file.
    :param duration: Duration in seconds to keep from the start of the video. Default is 300 seconds (5 minutes).
    """
    # Load the video file
    video = VideoFileClip(input_path)
    
    # Trim the video to the first 'duration' seconds
    trimmed_video = video.subclip(0, duration)
    
    # Write the trimmed video to a new file
    trimmed_video.write_videofile(output_path, codec="libx264")


input_video_path = "v1.mp4"
output_video_path = "v1_5min.mp4"
trim_video(input_video_path, output_video_path, 300)

# %% [markdown]
# # Export Video frames

# %%
import cv2
import os, re
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

def save_frame(frame, frame_filename):
    cv2.imwrite(frame_filename, frame)

def video_to_frames(video_path, output_folder=None, max_workers=8, frame_skip=0):
    start_time = time.time()
    
    # Get the base name of the video file (without extension)
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    
    # Set the default output folder if not provided
    if output_folder is None:
        output_folder = os.path.join(os.getcwd(), video_name)
    
    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Open the video file
    video_capture = cv2.VideoCapture(video_path)
    
    # Check if the video was opened successfully
    if not video_capture.isOpened():
        print(f"Error: Could not open video {video_path}")
        return
    
    frame_count = 0
    saved_frame_count = 0
    futures = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        while True:
            # Read the next frame from the video
            success, frame = video_capture.read()
            
            # If reading a frame was not successful, break the loop
            if not success:
                break
            
            # Save the frame if it's not being skipped
            if frame_count % (frame_skip + 1) == 0:
                # Construct the output file path
                frame_filename = os.path.join(output_folder, f"frame_{saved_frame_count:04d}.png")
                
                # Submit the frame saving task to the thread pool
                futures.append(executor.submit(save_frame, frame, frame_filename))
                
                saved_frame_count += 1
            
            frame_count += 1
    
    # Wait for all futures to complete
    for future in as_completed(futures):
        future.result()
    
    # Release the video capture object
    video_capture.release()
    
    end_time = time.time()
    total_time = end_time - start_time
    print(f"Extracted {saved_frame_count} frames to {output_folder} in {total_time:.2f} seconds")


video_to_frames("v2.mp4", frame_skip=20)
video_to_frames("v3.mp4", frame_skip=20)
video_to_frames("v4.mp4", frame_skip=20)
video_to_frames("v5.mp4", frame_skip=20)

# %%
import winshell
import keyboard

# Function to restore the last deleted item from the Recycle Bin
def restore_last_deleted_item():
    try:
        # Get the list of items in the Recycle Bin
        items = list(winshell.recycle_bin())
        
        if items:
            # Restore the last deleted item
            last_item = items[-1]
            last_item.restore()
            print(f"Successfully restored: {last_item.name}")
        else:
            print("No items found in the Recycle Bin.")
    except Exception as e:
        print(f"Failed to restore the last deleted item: {e}")

# Set up the hotkey to restore the last deleted item
hotkey = 'numlock'
keyboard.add_hotkey(hotkey, restore_last_deleted_item)

print(f"Press {hotkey} to restore the last deleted item from the Recycle Bin.")

# Keep the script running
keyboard.wait('esc')

# %% [markdown]
# # CSV to YOLO text annotations

# %%
import os
import pandas as pd

# Read the CSV data
data = pd.read_csv('labels_valomalo_2024-08-09-12-55-25.csv')

# Map class names to class IDs
class_mapping = {
    'Body': 0,
    'Head': 1
}

# Function to normalize coordinates
def normalize_bbox(x, y, width, height, img_width, img_height):
    x_center = (x + width / 2) / img_width
    y_center = (y + height / 2) / img_height
    norm_width = width / img_width
    norm_height = height / img_height
    return x_center, y_center, norm_width, norm_height

# Directory to save the annotation files
output_dir = 'annotations'
os.makedirs(output_dir, exist_ok=True)

# Process each row and write to corresponding text file
for _, row in data.iterrows():
    class_id = class_mapping[row['label_name']]
    x_center, y_center, norm_width, norm_height = normalize_bbox(
        row['bbox_x'], row['bbox_y'], row['bbox_width'], row['bbox_height'],
        row['image_width'], row['image_height']
    )
    
    # Format the annotation to six decimal places
    annotation = f"{class_id} {x_center:.6f} {y_center:.6f} {norm_width:.6f} {norm_height:.6f}\n"
    
    # Write to the corresponding text file in the specified directory
    txt_file_name = os.path.join(output_dir, row['image_name'].replace('.jpg', '.txt'))
    with open(txt_file_name, 'a') as f:
        f.write(annotation)

# %% [markdown]
# # Visualize images & their labels + option to extract to a new dir

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt

def get_label_color(label, label_colors, predefined_colors):
    if label in predefined_colors:
        return predefined_colors[label]
    if label not in label_colors:
        label_colors[label] = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))
    return label_colors[label]

def draw_bounding_boxes(image, label_path, label_colors, predefined_colors, thickness=2):
    height, width, _ = image.shape
    
    if os.path.exists(label_path):
        with open(label_path, 'r') as file:
            for line in file:
                parts = line.strip().split()
                label = int(parts[0])
                x_center, y_center, w, h = map(float, parts[1:])
                
                x_center *= width
                y_center *= height
                w *= width
                h *= height
                
                x1 = int(x_center - w / 2)
                y1 = int(y_center - h / 2)
                x2 = int(x_center + w / 2)
                y2 = int(y_center + h / 2)
                
                color = get_label_color(label, label_colors, predefined_colors)
                cv2.rectangle(image, (x1, y1), (x2, y2), color, thickness)
    return image

def visualize_images_with_labels(image_folder, label_folder, predefined_colors, thickness=2):
    label_colors = {}
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    for image_file in image_files:
        image_path = os.path.join(image_folder, image_file)
        label_path = os.path.join(label_folder, os.path.splitext(image_file)[0] + '.txt')
        
        image = cv2.imread(image_path)
        image = draw_bounding_boxes(image, label_path, label_colors, predefined_colors, thickness)
        
        # Print the image name to the console
        print(f"{image_file}")
        
        plt.figure(figsize=(10, 10))
        plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()

def save_images_with_labels(image_folder, label_folder, output_folder, predefined_colors, thickness=2):
    label_colors = {}
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for image_file in image_files:
        image_path = os.path.join(image_folder, image_file)
        label_path = os.path.join(label_folder, os.path.splitext(image_file)[0] + '.txt')
        
        image = cv2.imread(image_path)
        image = draw_bounding_boxes(image, label_path, label_colors, predefined_colors, thickness)
        
        # Save the image with bounding boxes to the output folder
        output_path = os.path.join(output_folder, image_file)
        cv2.imwrite(output_path, image)
        
        # Print the image name to the console
        print(f"Saved {image_file} to {output_folder}")

# Example usage
image_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_cutout_fix"
label_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels_cutout_fix"
output_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix"

# Define predefined colors for labels
predefined_colors = {
    1: (255, 0, 0),    # Red 
    0: (0, 255, 0),    # Green 
    # Add more predefined colors as needed
}

# Visualize images with labels
# visualize_images_with_labels(image_folder, label_folder, predefined_colors, thickness=3)

# Save images with labels to output folder
save_images_with_labels(image_folder, label_folder, output_folder, predefined_colors, thickness=2)
# Out:
# Saved image_1723283693.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283694.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283698.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283699.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283706.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283707.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283708.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283719.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283740.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283741.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283748.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283757.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283758.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283759.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283761.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283769.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283776.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283803.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283918.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283919.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283928.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283934.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283943.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283947.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283950.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283974.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283976.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283983.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723283998.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284004.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284028.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284045.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284046.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284075.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284076.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284082.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284118.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284119.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284126.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284127.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284152.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284153.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284154.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284155.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284156.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284157.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284158.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284159.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284211.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284212.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284246.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284247.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284275.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284276.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284277.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284284.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284285.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284286.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284290.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284291.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284303.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284308.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284309.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284310.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284314.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284349.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284350.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284352.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284355.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284356.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284357.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284358.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284368.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284380.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284392.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284425.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284470.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284471.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284472.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284473.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284495.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284496.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284497.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284502.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284507.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284508.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284542.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284562.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284568.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284569.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284570.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284571.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284575.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284576.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284581.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284589.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284598.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284599.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284604.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284605.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284611.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284629.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284630.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284655.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284669.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284670.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284671.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284672.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284728.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284749.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284750.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284752.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284766.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284767.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284769.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284770.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284780.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284781.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284800.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284802.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284803.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284811.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284818.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284820.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284857.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284859.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723284890.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285401.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285403.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285404.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285406.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285407.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285408.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285414.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285415.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285416.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285422.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285423.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285437.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285438.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285441.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285449.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285453.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285459.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285499.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285500.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285506.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285509.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285518.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285519.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285521.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285526.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285564.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285603.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285605.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285619.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285628.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285629.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285636.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285641.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285642.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285646.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285647.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285676.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285677.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285706.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285711.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285738.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285740.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285764.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285773.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285774.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285777.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285786.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285787.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285810.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285813.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285819.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285821.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285910.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285916.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285918.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285919.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285920.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285925.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285926.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285929.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285930.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285953.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285954.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285956.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285957.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285978.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723285979.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286007.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286013.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286014.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286040.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286041.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286049.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286050.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286058.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286059.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286060.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286061.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286065.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286109.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286111.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286112.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286114.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286119.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286120.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286121.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286124.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286125.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286126.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286127.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286145.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286153.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286154.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286159.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286160.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286161.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286167.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286168.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286169.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286189.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286190.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286191.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286195.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286196.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286197.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286201.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286221.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286231.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286250.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286251.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286252.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286289.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286291.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286292.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286293.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286315.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286316.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286317.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286325.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286349.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286352.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286357.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286359.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286366.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286367.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286369.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286386.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286417.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286418.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286420.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286421.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286422.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286423.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286454.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286460.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286473.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286474.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286516.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286527.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286557.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286583.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286584.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286585.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286636.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286638.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286649.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286650.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286651.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286697.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286704.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286706.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286793.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286794.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286795.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286796.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286802.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286810.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286812.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286813.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286833.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286834.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286853.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286855.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286856.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286868.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286873.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286874.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286881.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286882.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286883.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286913.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286914.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286917.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286922.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286933.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286934.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286935.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286936.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286938.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286939.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286940.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286942.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286943.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286944.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286945.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286950.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286951.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286961.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286962.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286967.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286969.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286973.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286974.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286976.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286980.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723286981.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287000.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287001.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287002.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287006.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287009.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287017.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287018.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287019.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287026.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287027.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287028.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287029.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287082.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287105.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287109.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287154.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287158.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287159.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287162.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287165.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287166.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287171.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287172.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287175.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287176.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287205.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287230.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287231.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287232.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287234.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287235.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287237.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287267.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287268.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287269.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287280.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287281.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287288.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287295.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287297.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287298.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287300.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287303.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287304.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287305.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287306.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287330.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287331.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287332.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287345.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287363.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287364.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287371.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287375.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287376.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287378.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287379.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287384.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287385.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287386.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287390.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287392.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287422.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287434.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287443.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287447.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287448.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287449.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287470.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287471.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287475.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287477.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287478.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287479.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287485.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287489.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287490.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287500.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287501.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287504.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287505.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287536.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287537.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287539.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287548.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287549.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287552.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287553.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287554.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287580.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287584.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287587.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287588.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287590.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287595.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287596.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287599.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287630.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287632.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287633.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287634.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287635.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287636.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287637.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287638.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287639.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287670.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287673.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287674.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287675.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287720.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287735.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287779.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287780.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287783.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287784.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287788.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287790.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287791.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287814.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287815.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287859.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287860.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287863.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287874.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287886.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287911.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287924.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287942.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723287943.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289221.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289222.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289224.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289235.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289236.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289260.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289265.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289266.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289295.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289297.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289301.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289303.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723289315.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# ...
# Saved image_1723309598.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309616.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309621.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309623.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309628.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309629.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309630.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309635.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309636.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309637.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309648.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309649.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309654.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309658.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309659.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309660.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309663.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309664.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309665.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309667.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309668.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309672.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309682.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309683.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309686.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309687.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309689.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309690.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309697.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309698.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309702.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309703.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309704.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309705.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309706.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309707.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309711.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309712.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309715.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309720.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309721.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309722.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309726.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309733.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309735.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309737.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309743.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309744.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309745.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309746.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309749.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309750.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309751.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309752.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309755.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309759.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309761.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309764.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309765.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309772.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309773.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309783.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309789.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309794.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309796.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309797.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309804.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309807.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309815.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309818.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309826.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309831.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309840.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309841.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309842.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309848.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309849.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309850.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309851.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309854.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309855.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309860.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309861.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309866.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309867.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309872.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309873.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309874.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309875.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309876.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309880.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723309885.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310803.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310804.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310805.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310806.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310807.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310812.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310813.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310818.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310819.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310831.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310832.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310833.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310838.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310839.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310840.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310843.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310846.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310869.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310870.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310876.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310882.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310884.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310888.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310889.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310890.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310891.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310897.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310900.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310907.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310918.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310922.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310924.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310925.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310926.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310932.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310935.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310936.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310938.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310947.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310955.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310956.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310960.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310961.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310962.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310963.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310968.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310969.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310978.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310979.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310990.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310991.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310992.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723310994.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311004.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311005.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311017.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311018.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311019.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311025.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311029.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311030.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311033.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix
# Saved image_1723311034.jpg to C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_with_labels_fix

# %% [markdown]
# # Extract a Cutout of the Image containing the Labels + save the new adjust labels

# %%
import os
import random
from PIL import Image

def extract_cutout(image_path, label_path, label_number, cutout_size):
    image = Image.open(image_path)
    width, height = image.size
    cutout_width, cutout_height = cutout_size

    # Ensure cutout size is not larger than the image dimensions
    cutout_width = min(cutout_width, width)
    cutout_height = min(cutout_height, height)

    labels = []
    target_labels = []

    # If label file exists, process it
    if os.path.exists(label_path):
        with open(label_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                parts = line.strip().split()
                label = int(parts[0])
                x_center = float(parts[1]) * width
                y_center = float(parts[2]) * height
                box_width = float(parts[3]) * width
                box_height = float(parts[4]) * height

                if label == label_number:
                    target_labels.append((label, x_center, y_center, box_width, box_height))

            if target_labels:
                # Calculate the bounding box that includes all target labels
                min_left = min(x_center - box_width / 2 for _, x_center, _, box_width, _ in target_labels)
                max_right = max(x_center + box_width / 2 for _, x_center, _, box_width, _ in target_labels)
                min_top = min(y_center - box_height / 2 for _, _, y_center, _, box_height in target_labels)
                max_bottom = max(y_center + box_height / 2 for _, _, y_center, _, box_height in target_labels)

                # Randomly position the cutout around the bounding box
                left = int(min_left - random.uniform(0.25, 0.75) * (cutout_width - (max_right - min_left)))
                top = int(min_top - random.uniform(0.25, 0.75) * (cutout_height - (max_bottom - min_top)))
                right = left + cutout_width
                bottom = top + cutout_height

                # Ensure the cutout is within image bounds
                left = max(0, min(left, width - cutout_width))
                top = max(0, min(top, height - cutout_height))
                right = left + cutout_width
                bottom = top + cutout_height

                cutout = image.crop((left, top, right, bottom))

                # Adjust all label coordinates within the cutout region
                for line in lines:
                    parts = line.strip().split()
                    label = int(parts[0])
                    x_center = float(parts[1]) * width
                    y_center = float(parts[2]) * height
                    box_width = float(parts[3]) * width
                    box_height = float(parts[4]) * height

                    if left <= x_center <= right and top <= y_center <= bottom:
                        new_x_center = (x_center - left) / cutout_width
                        new_y_center = (y_center - top) / cutout_height
                        new_box_width = box_width / cutout_width
                        new_box_height = box_height / cutout_height

                        # Clip the values to be within [0, 1]
                        new_x_center = min(max(new_x_center, 0), 1)
                        new_y_center = min(max(new_y_center, 0), 1)
                        new_box_width = min(max(new_box_width, 0), 1)
                        new_box_height = min(max(new_box_height, 0), 1)

                        labels.append((label, new_x_center, new_y_center, new_box_width, new_box_height))
                return cutout, labels

            # If no target labels found, use the next available label
            for line in lines:
                parts = line.strip().split()
                label = int(parts[0])
                x_center = float(parts[1]) * width
                y_center = float(parts[2]) * height
                box_width = float(parts[3]) * width
                box_height = float(parts[4]) * height

                # Randomly position the cutout around the label
                left = int(x_center - random.uniform(0.25, 0.75) * cutout_width)
                top = int(y_center - random.uniform(0.25, 0.75) * cutout_height)
                right = left + cutout_width
                bottom = top + cutout_height

                # Ensure the cutout is within image bounds
                left = max(0, min(left, width - cutout_width))
                top = max(0, min(top, height - cutout_height))
                right = left + cutout_width
                bottom = top + cutout_height

                cutout = image.crop((left, top, right, bottom))

                # Adjust all label coordinates within the cutout region
                for line in lines:
                    parts = line.strip().split()
                    label = int(parts[0])
                    x_center = float(parts[1]) * width
                    y_center = float(parts[2]) * height
                    box_width = float(parts[3]) * width
                    box_height = float(parts[4]) * height

                    if left <= x_center <= right and top <= y_center <= bottom:
                        new_x_center = (x_center - left) / cutout_width
                        new_y_center = (y_center - top) / cutout_height
                        new_box_width = box_width / cutout_width
                        new_box_height = box_height / cutout_height

                        # Clip the values to be within [0, 1]
                        new_x_center = min(max(new_x_center, 0), 1)
                        new_y_center = min(max(new_y_center, 0), 1)
                        new_box_width = min(max(new_box_width, 0), 1)
                        new_box_height = min(max(new_box_height, 0), 1)

                        labels.append((label, new_x_center, new_y_center, new_box_width, new_box_height))
                return cutout, labels
    else:
        # If no labels, extract a random region from the middle
        if width > cutout_width and height > cutout_height:
            left_min = max(0, width // 4)
            left_max = min(width - cutout_width, 3 * width // 4)
            top_min = max(0, height // 4)
            top_max = min(height - cutout_height, 3 * height // 4)

            left = random.randint(left_min, left_max)
            top = random.randint(top_min, top_max)
        else:
            left = (width - cutout_width) // 2
            top = (height - cutout_height) // 2

        right = left + cutout_width
        bottom = top + cutout_height

        cutout = image.crop((left, top, right, bottom))
        return cutout, labels

def process_images(image_folder, label_folder, label_number, cutout_size, output_folder, label_output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    if not os.path.exists(label_output_folder):
        os.makedirs(label_output_folder)

    for image_name in os.listdir(image_folder):
        if image_name.endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(image_folder, image_name)
            label_path = os.path.join(label_folder, os.path.splitext(image_name)[0] + '.txt')
            cutout, labels = extract_cutout(image_path, label_path, label_number, cutout_size)
            if cutout:
                cutout.save(os.path.join(output_folder, image_name))
                label_output_path = os.path.join(label_output_folder, os.path.splitext(image_name)[0] + '.txt')
                with open(label_output_path, 'w') as label_file:
                    if labels:
                        for label in labels:
                            label_file.write(f"{label[0]} {label[1]:.6f} {label[2]:.6f} {label[3]:.6f} {label[4]:.6f}\n")
                    else:
                        # Write an empty file for images with no labels
                        label_file.write("")

image_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\images"
label_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels"
label_number = 0 # The label to choose the cutouts upon
cutout_size = (640, 640)  
image_output_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_cutout_fix"
label_output_folder = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels_cutout_fix"

process_images(image_folder, label_folder, label_number, cutout_size, image_output_folder, label_output_folder)

# %% [markdown]
# # Split the main folder into TvT

# %%
import os, re
import random
import shutil

images_path = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\images_cutout"
labels_path = r"C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels_cutout"

# Preprocessing step: Delete .txt files that do not correspond to any image
label_files = [f for f in os.listdir(labels_path) if f.endswith('.txt')]
for label_file in label_files:
    image_file = label_file.replace('.txt', '.jpg')
    if not os.path.exists(os.path.join(images_path, image_file)):
        os.remove(os.path.join(labels_path, label_file))

# Get all image files
image_files = [f for f in os.listdir(images_path) if f.endswith('.jpg')]

# Shuffle the files
random.shuffle(image_files)

# Calculate split indices
total_images = len(image_files)
train_split = int(total_images * 0.7)
val_split = int(total_images * 0.2)

# Split the files
train_files = image_files[:train_split]
val_files = image_files[train_split:train_split + val_split]
test_files = image_files[train_split + val_split:]

# Copy files to their directories
def copy_files(file_list, dest_images_path, dest_labels_path):
    os.makedirs(dest_images_path, exist_ok=True)
    os.makedirs(dest_labels_path, exist_ok=True)
    for file in file_list:
        shutil.copy(os.path.join(images_path, file), dest_images_path)
        label_file = file.replace('.jpg', '.txt')
        if os.path.exists(os.path.join(labels_path, label_file)):
            shutil.copy(os.path.join(labels_path, label_file), dest_labels_path)

# Create directories and copy files
copy_files(train_files, 'yolo_dataset/train/images', 'yolo_dataset/train/labels')
copy_files(val_files, 'yolo_dataset/val/images', 'yolo_dataset/val/labels')
copy_files(test_files, 'yolo_dataset/test/images', 'yolo_dataset/test/labels')

# %% [markdown]
# # Copy images with no Labels into a new dir

# %%
import os, re
import shutil

def copy_images_without_labels(images_dir, labels_dir, dest_dir):
    # Ensure the destination directory exists
    os.makedirs(dest_dir, exist_ok=True)

    # Get the list of image files and label files
    image_files = [f for f in os.listdir(images_dir) if f.endswith(('.png', '.jpg', '.jpeg'))]
    label_files = [f for f in os.listdir(labels_dir) if f.endswith('.txt')]

    # Create a set of label filenames without extensions
    label_names = set(os.path.splitext(f)[0] for f in label_files)

    # Iterate through image files and copy those without corresponding labels
    for image_file in image_files:
        image_name, _ = os.path.splitext(image_file)
        if image_name not in label_names:
            src_path = os.path.join(images_dir, image_file)
            dest_path = os.path.join(dest_dir, image_file)
            shutil.copy(src_path, dest_path) # comment if you dont wanna copy or add logic
            print(f"Copied {image_file} to {dest_dir}")

images_directory = r'C:\Users\Vaquita\Downloads\Valomalo\final dataset\images'
labels_directory = r'C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels'
destination_directory = r'C:\Users\Vaquita\Downloads\Valomalo\final dataset\no_labels'

copy_images_without_labels(images_directory, labels_directory, destination_directory)

# %% [markdown]
# # Find closest match of images to the images in the bigger dir using an image hash

# %%
from PIL import Image
import imagehash
import os
from matplotlib import pyplot as plt

def load_images_from_folder(folder):
    images = []
    filenames = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        try:
            img = Image.open(img_path)
            images.append(img)
            filenames.append(filename)
        except Exception as e:
            print(f"Error loading image {filename}: {e}")
    return images, filenames

def compute_hash(image):
    return imagehash.average_hash(image)

def find_closest_image(hash_x, hashes_y):
    min_distance = float('inf')
    closest_index = -1
    for i, hash_y in enumerate(hashes_y):
        distance = hash_x - hash_y
        if distance < min_distance:
            min_distance = distance
            closest_index = i
    return closest_index, min_distance

def find_closest_images(dir_x, dir_y, threshold=float('inf'), display_results=False):
    images_x, filenames_x = load_images_from_folder(dir_x)
    images_y, filenames_y = load_images_from_folder(dir_y)

    hashes_x = [compute_hash(img) for img in images_x]
    hashes_y = [compute_hash(img) for img in images_y]

    results = []

    for i, hash_x in enumerate(hashes_x):
        closest_index, min_distance = find_closest_image(hash_x, hashes_y)
        if min_distance <= threshold:
            result = {
                'image_x': filenames_x[i],
                'closest_image_y': filenames_y[closest_index],
                'difference_score': min_distance
            }
            results.append(result)
            print(f"Image {filenames_x[i]} from X is closest to {filenames_y[closest_index]} from Y with a difference score of {min_distance}")

            if display_results:
                # Display the images
                plt.figure(figsize=(10, 5))
                plt.subplot(1, 2, 1)
                plt.title(f"Image from X: {filenames_x[i]}")
                plt.imshow(images_x[i])
                plt.axis('off')

                plt.subplot(1, 2, 2)
                plt.title(f"Closest Image from Y: {filenames_y[closest_index]}")
                plt.imshow(images_y[closest_index])
                plt.axis('off')

                plt.show()

    return results

dir_images_to_find = r'C:\Users\Vaquita\Downloads\Valomalo\test_benchmark_images'
dir_images_to_search = r"C:\Users\Vaquita\Downloads\Valomalo\test_benchmark_images"

threshold = 1  # Set your desired threshold here


results = find_closest_images(dir_images_to_find, dir_images_to_search, threshold=threshold, display_results=True)

# %%
# Store all the closest matches in a list
closest_matches = results

# Print the closest matches
for match in closest_matches:
    print(f"{match['closest_image_y']} ")

# %% [markdown]
# # copy files in a list into a new folder

# %%
import shutil
import os

def copy_files(file_list, source_dir, destination_dir):
    """
    Copies files from the source directory to the destination directory.

    :param file_list: List of filenames to be copied.
    :param source_dir: Directory where the files are currently located.
    :param destination_dir: Directory where the files should be copied to.
    """
    if not os.path.exists(destination_dir):
        os.makedirs(destination_dir)

    for filename in file_list:
        src_path = os.path.join(source_dir, filename)
        dest_path = os.path.join(destination_dir, filename)
        try:
            shutil.copy(src_path, dest_path)
            print(f"Copied {filename} to {destination_dir}")
        except Exception as e:
            print(f"Error copying {filename}: {e}")

source_dir = r'C:\Users\Vaquita\Downloads\Valomalo\Moamen - batch 1'
destination_dir = r'C:\Users\Vaquita\Downloads\Valomalo\Moamen - batch 1\copied_files'


# Extract the list of closest image filenames from Y
closest_image_filenames = [match['closest_image_y'] for match in closest_matches]

# Copy the closest image files to the new folder
copy_files(closest_image_filenames, source_dir, destination_dir)

# %% [markdown]
# # Visualize YOLO Augmentation

# %% [markdown]
# ## Approved Augs
# A.HorizontalFlip(p=0.5),
# A.RandomScale(scale_limit=0.2, p=0.5),  # Randomly scale the image with a 50% probability
# A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=20, p=1),  # Randomly shift, scale, and rotate the image with a 50% probability
# A.CoarseDropout(max_holes=8, max_height=128, max_width=128, p=1),  # Randomly drop rectangular regions of the image with a 50% probability

# %%
import os
import random
import cv2
import matplotlib.pyplot as plt
import albumentations as A

# Define paths
image_folder = r'C:\Users\Vaquita\Downloads\Valomalo\Moamen - batch 1'
label_folder = r'C:\Users\Vaquita\Downloads\Valomalo\Moamen - batch 1\labels_my-project-name_2024-08-14-10-47-42'

# Function to read YOLO format labels
def read_yolo_labels(label_path):
    with open(label_path, 'r') as file:
        labels = [line.strip().split() for line in file]
    return labels

# Function to draw bounding boxes on the image
def draw_boxes(image, boxes, color=(0, 255, 0)):
    h, w, _ = image.shape
    for box in boxes:
        class_id, x_center, y_center, width, height = map(float, box)
        x1 = int((x_center - width / 2) * w)
        y1 = int((y_center - height / 2) * h)
        x2 = int((x_center + width / 2) * w)
        y2 = int((y_center + height / 2) * h)
        cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
    return image

# Define augmentation pipeline
transform = A.Compose([
    #A.HorizontalFlip(p=0.5),  # Flip the image horizontally with a 50% probability
    A.RandomScale(scale_limit=0.5, p=1),  # Randomly scale the image with a 50% probability
    #A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.2, rotate_limit=20, p=1),  # Randomly shift, scale, and rotate the image with a 50% probability
    #A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),  # Randomly change brightness, contrast, saturation, and hue with a 50% probability
    #A.CoarseDropout(max_holes=8, max_height=128, max_width=128, p=1),  # Randomly drop rectangular regions of the image with a 50% probability
], bbox_params=A.BboxParams(format='yolo', label_fields=['class_labels']))

# Get list of images and labels
image_files = [f for f in os.listdir(image_folder) if f.endswith('.jpg')]
label_files = [f for f in os.listdir(label_folder) if f.endswith('.txt')]

# Select random images for visualization
random_images = random.sample(image_files, 5)

for image_file in random_images:
    # Read image
    image_path = os.path.join(image_folder, image_file)
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Read corresponding label
    label_path = os.path.join(label_folder, os.path.splitext(image_file)[0] + '.txt')
    labels = read_yolo_labels(label_path)
    
    # Extract bounding boxes and class labels
    bboxes = [list(map(float, label[1:])) for label in labels]
    class_labels = [label[0] for label in labels]
    
    # Apply augmentation
    augmented = transform(image=image, bboxes=bboxes, class_labels=class_labels)
    augmented_image = augmented['image']
    augmented_bboxes = augmented['bboxes']
    
    # Draw bounding boxes on original and augmented images
    image_with_boxes = draw_boxes(image.copy(), labels)
    augmented_image_with_boxes = draw_boxes(augmented_image.copy(), [[class_labels[i]] + list(bbox) for i, bbox in enumerate(augmented_bboxes)])
    
    # Plot the images
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))
    ax[0].imshow(image_with_boxes)
    ax[0].set_title('Original Image')
    ax[1].imshow(augmented_image_with_boxes)
    ax[1].set_title('Augmented Image')
    plt.show()

# %% [markdown]
# # Verify corrct annoations for YOLO

# %%
import os

def check_yolo_annotations(directory):
    """
    Reads all YOLO annotation .txt files in the specified directory and checks if any of the coordinates
    are outside the range [0, 1]. Prints the file names with errors and their annotations.
    
    :param directory: The directory containing YOLO annotation .txt files.
    """
    error_count = 0

    for filename in os.listdir(directory):
        if filename.endswith(".txt"):
            filepath = os.path.join(directory, filename)
            with open(filepath, 'r') as file:
                lines = file.readlines()
                for line in lines:
                    parts = line.strip().split()
                    if len(parts) != 5:
                        print(f"Error in file {filename}: Incorrect annotation format: {line.strip()}")
                        error_count += 1
                        continue
                    _, x_center, y_center, width, height = map(float, parts)
                    if not (0 <= x_center <= 1 and 0 <= y_center <= 1 and 0 <= width <= 1 and 0 <= height <= 1):
                        print(f"Error in file {filename}: {line.strip()}")
                        error_count += 1

    print(f"Total number of errors: {error_count}")

# Example usage
check_yolo_annotations(r'C:\Users\Vaquita\Downloads\Valomalo\final dataset\labels_cutout_fix')
# Out:
# Total number of errors: 0
